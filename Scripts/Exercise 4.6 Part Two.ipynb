# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
#Importing Path
path = r"C:\Users\abiya\01-2023 Instacart Basket Analysis"

# %%
# Importing orders_products_combined.pkl
df_orders_products_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Importing products_cleaned.csv
df_prods = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'prods_cleaned.csv'), index_col = False)

# %%
#Checking size of the df_orders_products_combined 
df_orders_products_combined.shape
# Out:
# (32434489, 13)

# %%
# Checking output for df_orders_products_combined
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8               11.114836         196
# 1          2                  8               11.114836       14084
# 2          2                  8               11.114836       12427
# 3          2                  8               11.114836       26088
# 4          2                  8               11.114836       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
# Checking size of the df_prods
df_prods.shape
# Out:
# (49693, 6)

# %%
# Checking output for df_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Dropping unnamed column for df_prods
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Checking output for df_prods after dropping the unnamed column
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Dropping '_merge' column for df_orders_products_combined
df_orders_products_combined = df_orders_products_combined.drop(columns = ['_merge'])

# %%
#Merging df_orders_products_combined with df_prods
df_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
# Checking output for df_merged
df_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8               11.114836         196
# 1          3                  7               15.000000         196
# 2          3                 12               21.000000         196
# 3          4                  7               29.000000         196
# 4          4                 15               28.000000         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# ...

# %%
#Checking value counts for '_merge' column
df_merged['_merge'].value_counts()
# Out:
# both          32434212
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Checking size of the df_merged
df_merged.shape
# Out:
# (32434212, 17)

# %%
#Exporting df_merged as orders_products_merged
df_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged.pkl'))
